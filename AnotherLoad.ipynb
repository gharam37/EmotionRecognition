# %%
import scipy.io
import os
from multiprocessing import Pool
import sys
import numpy as np
chan = ['Fp1','AF3','F3','F7','FC5','FC1','C3','T7','CP5','CP1','P3','P7','PO3','O1','Oz','Pz','Fp2','AF4','Fz','F4','F8','FC6','FC2','Cz','C4','T8','CP6','CP2','P4','P8','PO4','O2']
nLabel, nTrial, nUser, nChannel, nTime  = 4, 40, 32, 32, 8064
print("Program started \n")
fout_labels0 = open("label1.csv",'w')
fout_labels1 = open("label2.csv",'w')
fout_labels2 = open("labels3.csv",'w')
fout_labels3 = open("labels4.csv",'w')
for i in range(nUser):#4, 40, 32, 32, 8064
	if i < 10:
		name = '%0*d' % (2,i+1)
	else:
		name = i+1
	fname = "Users/s"+str(name)+".mat"
	x = scipy.io.loadmat(fname)
	print(fname)
	for tr in range(nTrial):
		fout_data = open("featuresraw.csv",'w')
		for ch in chan:
			fout_data.write(ch+",")
		fout_data.write("\n")
		for dat in range(nTime):
			for ch in range(nChannel):
				if ch <32:
					if ch == 31:
						fout_data.write(str(x['data'][tr][ch][dat]));	
					else:					
						fout_data.write(str(x['data'][tr][ch][dat])+",");
			fout_data.write("\n");
		fout_labels0.write(str(x['labels'][tr][0]) + "\n");
		fout_labels1.write(str(x['labels'][tr][1]) + "\n");
		fout_labels2.write(str(x['labels'][tr][2]) + "\n");
		fout_labels3.write(str(x['labels'][tr][3]) + "\n");
		fout_data.close()
		os.system('python creating_vector.py')
		print("user "+ str(i) +" trail"+ str(tr))
fout_labels0.close()
fout_labels1.close()
fout_labels2.close()
fout_labels3.close()
print("\n"+"Print Successful" )
# Out:
# Program started
#
# Users/s01.mat
# user 0 trail0
# user 0 trail1
# user 0 trail2
# user 0 trail3
# user 0 trail4
# user 0 trail5
# user 0 trail6
# user 0 trail7
# user 0 trail8
# user 0 trail9
# user 0 trail10
# user 0 trail11
# user 0 trail12
# user 0 trail13
# user 0 trail14
# user 0 trail15
# user 0 trail16
# user 0 trail17
# user 0 trail18
# user 0 trail19
# user 0 trail20
# user 0 trail21
# user 0 trail22
# user 0 trail23
# user 0 trail24
# user 0 trail25
# user 0 trail26
# user 0 trail27
# user 0 trail28
# user 0 trail29
# user 0 trail30
# user 0 trail31
# user 0 trail32
# user 0 trail33
# user 0 trail34
# user 0 trail35
# user 0 trail36
# user 0 trail37
# user 0 trail38
# user 0 trail39
# Users/s02.mat
# user 1 trail0
# user 1 trail1
# user 1 trail2
# user 1 trail3
# user 1 trail4
# user 1 trail5
# user 1 trail6
# user 1 trail7
# user 1 trail8
# user 1 trail9
# user 1 trail10
# user 1 trail11
# user 1 trail12
# user 1 trail13
# user 1 trail14
# user 1 trail15
# user 1 trail16
# user 1 trail17
# user 1 trail18
# user 1 trail19
# user 1 trail20
# user 1 trail21
# user 1 trail22
# user 1 trail23
# user 1 trail24
# user 1 trail25
# user 1 trail26
# user 1 trail27
# user 1 trail28
# user 1 trail29
# user 1 trail30
# user 1 trail31
# user 1 trail32
# user 1 trail33
# user 1 trail34
# user 1 trail35
# user 1 trail36
# user 1 trail37
# user 1 trail38
# user 1 trail39
# Users/s03.mat
# user 2 trail0
# user 2 trail1
# user 2 trail2
# user 2 trail3
# user 2 trail4
# user 2 trail5
# user 2 trail6
# user 2 trail7
# user 2 trail8
# user 2 trail9
# user 2 trail10
# user 2 trail11
# user 2 trail12
# user 2 trail13
# user 2 trail14
# user 2 trail15
# user 2 trail16
# user 2 trail17
# user 2 trail18
# user 2 trail19
# user 2 trail20
# user 2 trail21
# user 2 trail22
# user 2 trail23
# user 2 trail24
# user 2 trail25
# user 2 trail26
# user 2 trail27
# user 2 trail28
# user 2 trail29
# user 2 trail30
# user 2 trail31
# user 2 trail32
# user 2 trail33
# user 2 trail34
# user 2 trail35
# user 2 trail36
# user 2 trail37
# user 2 trail38
# user 2 trail39
# Users/s04.mat
# user 3 trail0
# user 3 trail1
# user 3 trail2
# user 3 trail3
# user 3 trail4
# user 3 trail5
# user 3 trail6
# user 3 trail7
# user 3 trail8
# user 3 trail9
# user 3 trail10
# user 3 trail11
# user 3 trail12
# user 3 trail13
# user 3 trail14
# user 3 trail15
# user 3 trail16
# user 3 trail17
# user 3 trail18
# user 3 trail19
# user 3 trail20
# user 3 trail21
# user 3 trail22
# user 3 trail23
# user 3 trail24
# user 3 trail25
# user 3 trail26
# user 3 trail27
# user 3 trail28
# user 3 trail29
# user 3 trail30
# user 3 trail31
# user 3 trail32
# user 3 trail33
# user 3 trail34
# user 3 trail35
# user 3 trail36
# user 3 trail37
# user 3 trail38
# user 3 trail39
# Users/s05.mat
# user 4 trail0
# user 4 trail1
# user 4 trail2
# user 4 trail3
# user 4 trail4
# user 4 trail5
# user 4 trail6
# user 4 trail7
# user 4 trail8
# user 4 trail9
# user 4 trail10
# user 4 trail11
# user 4 trail12
# user 4 trail13
# user 4 trail14
# user 4 trail15
# user 4 trail16
# user 4 trail17
# user 4 trail18
# user 4 trail19
# user 4 trail20
# user 4 trail21
# user 4 trail22
# user 4 trail23
# user 4 trail24
# user 4 trail25
# user 4 trail26
# user 4 trail27
# user 4 trail28
# user 4 trail29
# user 4 trail30
# user 4 trail31
# user 4 trail32
# user 4 trail33
# user 4 trail34
# user 4 trail35
# user 4 trail36
# user 4 trail37
# user 4 trail38
# user 4 trail39
# Users/s06.mat
# user 5 trail0
# user 5 trail1
# user 5 trail2
# user 5 trail3
# user 5 trail4
# user 5 trail5
# user 5 trail6
# user 5 trail7
# user 5 trail8
# user 5 trail9
# user 5 trail10
# user 5 trail11
# user 5 trail12
# user 5 trail13
# user 5 trail14
# user 5 trail15
# user 5 trail16
# user 5 trail17
# user 5 trail18
# user 5 trail19
# user 5 trail20
# user 5 trail21
# user 5 trail22
# user 5 trail23
# user 5 trail24
# user 5 trail25
# user 5 trail26
# user 5 trail27
# user 5 trail28
# user 5 trail29
# user 5 trail30
# user 5 trail31
# user 5 trail32
# user 5 trail33
# user 5 trail34
# user 5 trail35
# user 5 trail36
# user 5 trail37
# user 5 trail38
# user 5 trail39
# Users/s07.mat
# user 6 trail0
# user 6 trail1
# user 6 trail2
# user 6 trail3
# user 6 trail4
# user 6 trail5
# user 6 trail6
# user 6 trail7
# user 6 trail8
# user 6 trail9
# user 6 trail10
# user 6 trail11
# user 6 trail12
# user 6 trail13
# user 6 trail14
# user 6 trail15
# user 6 trail16
# user 6 trail17
# user 6 trail18
# user 6 trail19
# user 6 trail20
# user 6 trail21
# user 6 trail22
# user 6 trail23
# user 6 trail24
# user 6 trail25
# user 6 trail26
# user 6 trail27
# user 6 trail28
# user 6 trail29
# user 6 trail30
# user 6 trail31
# user 6 trail32
# user 6 trail33
# user 6 trail34
# user 6 trail35
# user 6 trail36
# user 6 trail37
# user 6 trail38
# user 6 trail39
# Users/s08.mat
# user 7 trail0
# user 7 trail1
# user 7 trail2
# user 7 trail3
# user 7 trail4
# user 7 trail5
# user 7 trail6
# user 7 trail7
# user 7 trail8
# user 7 trail9
# user 7 trail10
# user 7 trail11
# user 7 trail12
# user 7 trail13
# user 7 trail14
# user 7 trail15
# user 7 trail16
# user 7 trail17
# user 7 trail18
# user 7 trail19
# user 7 trail20
# user 7 trail21
# user 7 trail22
# user 7 trail23
# user 7 trail24
# user 7 trail25
# user 7 trail26
# user 7 trail27
