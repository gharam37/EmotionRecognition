# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import pandas as pd
import os
import collections
from sklearn.model_selection import ShuffleSplit
######### Valence And Arousal
def SVMPCA(Components,UserName,Window,StartTime=0,EndTime=63):
    file_path = os.path.join("ChannelsExtracted",UserName, 'ArousalEncoded'+".csv")
    ArousalFile =  np.genfromtxt(fname=file_path,delimiter=',').astype(int)
    file_path = os.path.join("ChannelsExtracted",UserName, 'ValenceEncoded'+".csv")
    ValenceFile =  np.genfromtxt(fname=file_path,delimiter=',').astype(int)
    BandsFile = np.genfromtxt('training/'+str(StartTime)+str(EndTime)+'/'+Window+UserName+'.csv',delimiter=',')
    X_train, X_test, y_train, y_test , z_train,z_test= train_test_split(BandsFile, ValenceFile,ArousalFile, test_size=0.2)
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    # PCA to select features
    pca = PCA(n_components=Components, svd_solver='full')
    pca.fit(BandsFile)
    BandsFile = pca.transform(BandsFile)
    #Predict Valence SVM and PCA
    clf = SVC()
    clf.fit(X_train, y_train)
    y_predict = clf.predict(X_test)
    #Predict Arousal SVM and PCA
    # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
        
    # PCA to select features
    pca = PCA(n_components=Components, svd_solver='full')
    pca.fit(BandsFile)
    BandsFile = pca.transform(BandsFile)
    clf = SVC()
    clf.fit(X_train, z_train)
    z_predict = clf.predict(X_test)
    return [accuracy_score(z_test, z_predict)*100,accuracy_score(y_test, y_predict)*100
            ,f1_score(z_test, z_predict, average='weighted'),
            f1_score(y_test, y_predict, average='weighted')]

######### Happy And sad ##############
def SVMPCAHS(Components,UserName,Window,StartTime=0,EndTime=63):
    file_path = os.path.join("ChannelsExtracted",UserName, 'HappyAndSadEncoded'+".csv")
    SurveyFile =  np.genfromtxt(fname=file_path,delimiter=',').astype(int)
    BandsFile = np.genfromtxt('training/'+str(StartTime)+str(EndTime)+'/'+str(Window)+UserName+'HS'+'.csv',delimiter=',')
    X_train, X_test, y_train, y_test = train_test_split(BandsFile, SurveyFile, test_size=0.2)
    while ((np.sum(y_train == 0) == 0) or (np.sum(y_train == 1) == 0)): #Don't Start training unless you have 2 classes.. happens with imbalance
        print("here")
        X_train, X_test, y_train, y_test = train_test_split(BandsFile, SurveyFile, test_size=0.2)
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    # PCA to select features
    pca = PCA(n_components=Components, svd_solver='full')
    pca.fit(BandsFile)
    BandsFile = pca.transform(BandsFile)
    #Predict Valence SVM and PCA
    clf = SVC()
    clf.fit(X_train, y_train)
    y_predict = clf.predict(X_test)
    return [accuracy_score(y_test, y_predict)*100,
            f1_score(y_test, y_predict, average='weighted')]

######### All Emotions##############
def SVMPCACombined(Components,UserName,Window,StartTime=0,EndTime=63):
    file_path = os.path.join("ChannelsExtracted",UserName, 'ValenceAndArousalEncoded'+".csv")
    SurveyFile =  np.genfromtxt(fname=file_path,delimiter=',').astype(int)
    BandsFile = np.genfromtxt('training/'+str(StartTime)+str(EndTime)+'/'+str(Window)+UserName+'.csv',delimiter=',')
    X_train, X_test, y_train, y_test = train_test_split(BandsFile, SurveyFile, test_size=0.2)
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    # PCA to select features
    pca = PCA(n_components=Components, svd_solver='full')
    pca.fit(BandsFile)
    BandsFile = pca.transform(BandsFile)
    #Predict Valence SVM and PCA
    clf = SVC()
    clf.fit(X_train, y_train)
    y_predict = clf.predict(X_test)
    return [accuracy_score(y_test, y_predict)*100,
            f1_score(y_test, y_predict, average='weighted')]



def Run100(Components,UserName,Window,StartTime=0,EndTime=63):
    arousal=[]
    valence=[]
    F1_ScoreArousal=[]
    F1_ScoreValence=[]
    for i in range (100):
        svm=SVMPCA(Components,UserName,Window,StartTime,EndTime)
        arousal+=[svm[0]]
        valence+=[svm[1]]
        F1_ScoreArousal+=[svm[2]]
        F1_ScoreValence+=[svm[3]]
    print("Arousal "+str(np.mean(arousal)))
    print(collections.Counter(arousal))
    print("Valence "+str(np.mean(valence)))
    print(collections.Counter(valence))
    return [np.mean(arousal),np.mean(valence),np.mean(F1_ScoreArousal),np.mean(F1_ScoreValence)];
        

    
if __name__ == "__main__":
     for i in range(100):
            Run1000(30,"s21","256",30,35) 
#     for i in range(1,10):
#         print("Whole video result for user s0"+str(i))
#         Run1000(20,"s0"+str(i),"256")  
#     for i in range(10,33):
#         print("Whole video result for user s"+str(i))
#         Run1000(20,"s"+str(i),"256")
# Out:
# Arousal 81.25
# Counter({87.5: 5, 75.0: 2, 62.5: 2, 100.0: 1})
# Valence 56.25
# Counter({62.5: 6, 50.0: 3, 37.5: 1})
# Arousal 81.25
# Counter({87.5: 5, 75.0: 3, 50.0: 1, 100.0: 1})
# Valence 58.75
# Counter({75.0: 4, 50.0: 2, 25.0: 1, 12.5: 1, 62.5: 1, 87.5: 1})
# Arousal 82.5
# Counter({87.5: 4, 100.0: 2, 62.5: 2, 75.0: 2})
# Valence 70.0
# Counter({75.0: 5, 62.5: 3, 50.0: 1, 87.5: 1})
# Arousal 78.75
# Counter({87.5: 5, 75.0: 2, 50.0: 2, 100.0: 1})
# Valence 60.0
# Counter({62.5: 3, 75.0: 3, 50.0: 3, 37.5: 1})
# Arousal 72.5
# Counter({87.5: 4, 75.0: 3, 50.0: 3})
# Valence 60.0
# Counter({50.0: 4, 75.0: 2, 62.5: 2, 37.5: 1, 87.5: 1})
# Arousal 78.75
# Counter({75.0: 4, 87.5: 3, 62.5: 2, 100.0: 1})
# Valence 51.25
# Counter({62.5: 4, 37.5: 2, 50.0: 2, 75.0: 1, 12.5: 1})
# Arousal 80.0
# Counter({87.5: 4, 75.0: 3, 62.5: 2, 100.0: 1})
# Valence 53.75
# Counter({37.5: 3, 75.0: 3, 62.5: 3, 12.5: 1})
# Arousal 82.5
# Counter({87.5: 6, 75.0: 2, 100.0: 1, 50.0: 1})
# Valence 66.25
# Counter({50.0: 3, 62.5: 3, 87.5: 2, 75.0: 2})
# Arousal 82.5
# Counter({87.5: 4, 62.5: 2, 100.0: 2, 75.0: 2})
# Valence 55.0
# Counter({50.0: 3, 37.5: 3, 62.5: 2, 87.5: 1, 75.0: 1})
# Arousal 82.5
# Counter({87.5: 6, 75.0: 2, 100.0: 1, 50.0: 1})
# Valence 52.5
# Counter({62.5: 4, 37.5: 2, 50.0: 2, 25.0: 1, 75.0: 1})
# Arousal 73.75
# Counter({87.5: 4, 62.5: 3, 75.0: 2, 50.0: 1})
# Valence 55.0
# Counter({50.0: 4, 62.5: 3, 37.5: 2, 87.5: 1})
# Arousal 77.5
# Counter({75.0: 5, 62.5: 2, 87.5: 2, 100.0: 1})
# Valence 70.0
# Counter({75.0: 4, 50.0: 3, 100.0: 1, 62.5: 1, 87.5: 1})
# Arousal 78.75
# Counter({87.5: 4, 62.5: 3, 75.0: 2, 100.0: 1})
# Valence 57.5
# Counter({50.0: 5, 62.5: 2, 75.0: 1, 37.5: 1, 87.5: 1})
# Arousal 81.25
# Counter({87.5: 4, 75.0: 4, 62.5: 1, 100.0: 1})
# Valence 62.5
# Counter({75.0: 2, 62.5: 2, 87.5: 2, 50.0: 2, 37.5: 2})
# Arousal 78.75
# Counter({87.5: 5, 62.5: 2, 100.0: 1, 75.0: 1, 50.0: 1})
# Valence 67.5
# Counter({75.0: 4, 37.5: 2, 62.5: 2, 87.5: 2})
# Arousal 80.0
# Counter({75.0: 4, 87.5: 2, 62.5: 2, 100.0: 2})
# Valence 63.75
# Counter({75.0: 4, 62.5: 3, 50.0: 3})
# Arousal 78.75
# Counter({75.0: 6, 87.5: 2, 100.0: 1, 62.5: 1})
# Valence 50.0
# Counter({50.0: 6, 37.5: 2, 62.5: 2})
# Arousal 78.75
# Counter({87.5: 5, 75.0: 3, 62.5: 2})
# Valence 61.25
# Counter({75.0: 3, 37.5: 2, 50.0: 2, 62.5: 2, 87.5: 1})
# Arousal 72.5
# Counter({75.0: 6, 62.5: 2, 50.0: 1, 100.0: 1})
# Valence 50.0
# Counter({50.0: 3, 62.5: 2, 0.0: 1, 25.0: 1, 87.5: 1, 75.0: 1, 37.5: 1})
# Arousal 73.75
# Counter({75.0: 4, 87.5: 3, 62.5: 2, 50.0: 1})
# Valence 60.0
# Counter({75.0: 3, 50.0: 3, 37.5: 2, 62.5: 1, 87.5: 1})
# Arousal 85.0
# Counter({87.5: 6, 75.0: 3, 100.0: 1})
# Valence 65.0
# Counter({50.0: 4, 75.0: 4, 87.5: 1, 62.5: 1})
# Arousal 77.5
# Counter({75.0: 4, 87.5: 3, 62.5: 1, 100.0: 1, 50.0: 1})
# Valence 52.5
# Counter({62.5: 3, 25.0: 2, 37.5: 2, 50.0: 1, 75.0: 1, 87.5: 1})
# Arousal 77.5
# Counter({87.5: 4, 75.0: 2, 62.5: 2, 100.0: 1, 50.0: 1})
# Valence 62.5
# Counter({75.0: 4, 50.0: 4, 62.5: 2})
# Arousal 87.5
# Counter({100.0: 4, 75.0: 4, 87.5: 2})
# Valence 63.75
# Counter({62.5: 5, 75.0: 4, 25.0: 1})
# Arousal 81.25
# Counter({100.0: 4, 87.5: 2, 50.0: 2, 62.5: 1, 75.0: 1})
# Valence 58.75
# Counter({62.5: 5, 50.0: 4, 75.0: 1})
# Arousal 75.0
# Counter({87.5: 4, 75.0: 3, 62.5: 2, 50.0: 1})
# Valence 61.25
# Counter({50.0: 3, 87.5: 2, 62.5: 2, 75.0: 2, 12.5: 1})
# Arousal 80.0
# Counter({75.0: 5, 87.5: 3, 100.0: 1, 62.5: 1})
# Valence 70.0
# Counter({87.5: 3, 62.5: 3, 50.0: 2, 75.0: 2})
# Arousal 77.5
# Counter({75.0: 5, 87.5: 3, 37.5: 1, 100.0: 1})
# Valence 67.5
# Counter({62.5: 3, 50.0: 3, 75.0: 2, 87.5: 1, 100.0: 1})
# Arousal 80.0
# Counter({87.5: 5, 75.0: 2, 62.5: 1, 100.0: 1, 50.0: 1})
# Valence 58.75
# Counter({75.0: 4, 37.5: 3, 25.0: 1, 62.5: 1, 87.5: 1})
# Arousal 76.25
# Counter({87.5: 5, 62.5: 2, 50.0: 2, 100.0: 1})
# Valence 65.0
# Counter({75.0: 3, 50.0: 3, 62.5: 3, 87.5: 1})
# Arousal 75.0
# Counter({62.5: 3, 75.0: 3, 100.0: 2, 87.5: 1, 50.0: 1})
# Valence 56.25
# Counter({62.5: 4, 50.0: 3, 37.5: 2, 87.5: 1})
# Arousal 72.5
# Counter({87.5: 4, 62.5: 3, 100.0: 1, 50.0: 1, 37.5: 1})
# Valence 66.25
# Counter({75.0: 5, 62.5: 3, 50.0: 2})
# Arousal 75.0
# Counter({75.0: 4, 62.5: 3, 87.5: 3})
# Valence 65.0
# Counter({62.5: 4, 75.0: 2, 25.0: 1, 87.5: 1, 37.5: 1, 100.0: 1})
# Arousal 72.5
# Counter({75.0: 4, 87.5: 3, 50.0: 2, 62.5: 1})
# Valence 53.75
# Counter({75.0: 4, 37.5: 4, 62.5: 1, 25.0: 1})
# Arousal 77.5
# Counter({87.5: 4, 75.0: 4, 62.5: 2})
# Valence 70.0
# Counter({75.0: 4, 50.0: 2, 87.5: 2, 62.5: 2})
# Arousal 75.0
# Counter({87.5: 3, 62.5: 2, 100.0: 2, 50.0: 1, 37.5: 1, 75.0: 1})
# Valence 67.5
# Counter({75.0: 4, 50.0: 2, 87.5: 2, 37.5: 1, 62.5: 1})
# Arousal 83.75
# Counter({75.0: 4, 100.0: 3, 87.5: 2, 62.5: 1})
# Valence 63.75
# Counter({75.0: 4, 62.5: 2, 37.5: 2, 87.5: 1, 50.0: 1})
# Arousal 76.25
# Counter({75.0: 5, 87.5: 2, 62.5: 1, 100.0: 1, 50.0: 1})
# Valence 63.75
# Counter({62.5: 3, 75.0: 3, 50.0: 2, 37.5: 1, 87.5: 1})
# Arousal 81.25
# Counter({87.5: 5, 75.0: 3, 50.0: 1, 100.0: 1})
# Valence 67.5
# Counter({75.0: 5, 50.0: 3, 87.5: 1, 62.5: 1})
# Arousal 77.5
# Counter({75.0: 5, 87.5: 2, 62.5: 2, 100.0: 1})
# Valence 57.5
# Counter({75.0: 3, 50.0: 2, 37.5: 2, 62.5: 1, 87.5: 1, 25.0: 1})
# Arousal 68.75
# Counter({75.0: 5, 62.5: 2, 50.0: 2, 87.5: 1})
# Valence 62.5
# Counter({62.5: 4, 50.0: 3, 75.0: 3})
# Arousal 81.25
# Counter({87.5: 4, 75.0: 4, 62.5: 1, 100.0: 1})
# Valence 63.75
# Counter({62.5: 3, 50.0: 2, 87.5: 2, 37.5: 2, 100.0: 1})
# Arousal 73.75
# Counter({75.0: 5, 87.5: 3, 50.0: 2})
# Valence 67.5
# Counter({75.0: 5, 62.5: 2, 37.5: 1, 87.5: 1, 50.0: 1})
# Arousal 81.25
# Counter({87.5: 4, 62.5: 3, 100.0: 2, 75.0: 1})
# Valence 56.25
# Counter({62.5: 4, 50.0: 3, 37.5: 2, 87.5: 1})
# Arousal 80.0
# Counter({87.5: 6, 75.0: 3, 50.0: 1})
# Valence 58.75
# Counter({50.0: 5, 62.5: 3, 75.0: 2})
# Arousal 76.25
# Counter({75.0: 5, 87.5: 3, 62.5: 2})
# Valence 62.5
# Counter({62.5: 5, 75.0: 3, 37.5: 1, 50.0: 1})
# Arousal 76.25
# Counter({75.0: 5, 87.5: 3, 62.5: 2})
# Valence 55.0
# Counter({62.5: 3, 87.5: 2, 75.0: 1, 37.5: 1, 0.0: 1, 25.0: 1, 50.0: 1})
# Arousal 80.0
# Counter({87.5: 6, 75.0: 2, 62.5: 2})
# Valence 55.0
# Counter({50.0: 4, 62.5: 4, 25.0: 1, 75.0: 1})
# Arousal 83.75
# Counter({87.5: 7, 62.5: 2, 100.0: 1})
# Valence 57.5
# Counter({62.5: 3, 75.0: 3, 50.0: 2, 37.5: 1, 25.0: 1})
# Arousal 82.5
# Counter({62.5: 3, 100.0: 3, 87.5: 3, 75.0: 1})
# Valence 65.0
# Counter({62.5: 4, 75.0: 4, 50.0: 2})
# Arousal 82.5
# Counter({87.5: 4, 62.5: 2, 75.0: 2, 100.0: 2})
# Valence 60.0
# Counter({50.0: 4, 62.5: 4, 75.0: 2})
# Arousal 75.0
# Counter({75.0: 5, 87.5: 3, 50.0: 1, 62.5: 1})
# Valence 68.75
# Counter({62.5: 4, 75.0: 4, 87.5: 1, 50.0: 1})
# Arousal 83.75
# Counter({87.5: 4, 75.0: 3, 100.0: 2, 62.5: 1})
# Valence 56.25
# Counter({37.5: 4, 62.5: 3, 100.0: 1, 75.0: 1, 50.0: 1})
# Arousal 81.25
# Counter({75.0: 6, 87.5: 3, 100.0: 1})
# Valence 57.5
# Counter({50.0: 5, 37.5: 2, 75.0: 2, 100.0: 1})
# Arousal 81.25
# Counter({87.5: 5, 62.5: 2, 75.0: 2, 100.0: 1})
# Valence 67.5
# Counter({75.0: 5, 37.5: 2, 87.5: 2, 50.0: 1})
# Arousal 81.25
# Counter({87.5: 6, 75.0: 3, 62.5: 1})
# Valence 65.0
# Counter({75.0: 3, 62.5: 3, 50.0: 3, 87.5: 1})
# Arousal 72.5
# Counter({87.5: 3, 62.5: 3, 75.0: 3, 50.0: 1})
# Valence 55.0
# Counter({50.0: 4, 75.0: 2, 37.5: 2, 62.5: 2})
# Arousal 77.5
# Counter({75.0: 5, 62.5: 2, 87.5: 2, 100.0: 1})
# Valence 57.5
# Counter({37.5: 2, 87.5: 2, 50.0: 2, 62.5: 2, 75.0: 1, 25.0: 1})
# Arousal 77.5
# Counter({75.0: 6, 100.0: 2, 37.5: 1, 87.5: 1})
# Valence 65.0
# Counter({62.5: 3, 50.0: 2, 87.5: 2, 75.0: 2, 37.5: 1})
# Arousal 75.0
# Counter({75.0: 4, 62.5: 2, 87.5: 2, 100.0: 1, 50.0: 1})
# Valence 62.5
# Counter({75.0: 4, 62.5: 3, 50.0: 2, 37.5: 1})
# Arousal 78.75
# Counter({87.5: 5, 75.0: 3, 62.5: 2})
# Valence 67.5
# Counter({62.5: 3, 75.0: 3, 87.5: 2, 37.5: 1, 50.0: 1})
# Arousal 81.25
# Counter({75.0: 5, 100.0: 3, 50.0: 1, 87.5: 1})
# Valence 70.0
# Counter({75.0: 3, 50.0: 3, 87.5: 3, 62.5: 1})
# Arousal 82.5
# Counter({87.5: 4, 100.0: 2, 62.5: 2, 75.0: 2})
# Valence 46.25
# Counter({50.0: 3, 37.5: 3, 25.0: 2, 75.0: 2})
# Arousal 67.5
# Counter({75.0: 5, 62.5: 2, 37.5: 1, 50.0: 1, 87.5: 1})
# Valence 57.5
# Counter({50.0: 3, 62.5: 3, 37.5: 2, 87.5: 1, 75.0: 1})
# Arousal 75.0
# Counter({75.0: 4, 87.5: 2, 62.5: 2, 100.0: 1, 50.0: 1})
# Valence 61.25
# Counter({50.0: 3, 62.5: 3, 75.0: 2, 37.5: 1, 87.5: 1})
# Arousal 76.25
# Counter({75.0: 3, 87.5: 2, 100.0: 2, 50.0: 2, 62.5: 1})
# Valence 70.0
# Counter({62.5: 4, 75.0: 4, 50.0: 1, 100.0: 1})
# Arousal 77.5
# Counter({75.0: 6, 100.0: 2, 62.5: 2})
# Valence 60.0
# Counter({75.0: 3, 50.0: 3, 37.5: 2, 87.5: 1, 62.5: 1})
# Arousal 75.0
# Counter({87.5: 4, 62.5: 2, 50.0: 2, 75.0: 1, 100.0: 1})
# Valence 63.75
# Counter({50.0: 3, 75.0: 2, 87.5: 2, 62.5: 2, 37.5: 1})
# Arousal 73.75
# Counter({75.0: 4, 87.5: 3, 62.5: 2, 50.0: 1})
# Valence 60.0
# Counter({62.5: 5, 75.0: 2, 50.0: 2, 37.5: 1})
# Arousal 77.5
# Counter({87.5: 4, 75.0: 4, 62.5: 2})
# Valence 67.5
# Counter({75.0: 3, 37.5: 2, 62.5: 2, 100.0: 2, 50.0: 1})
# Arousal 82.5
# Counter({75.0: 4, 87.5: 3, 100.0: 2, 62.5: 1})
# Valence 63.75
# Counter({62.5: 7, 75.0: 2, 50.0: 1})
# Arousal 70.0
# Counter({62.5: 4, 75.0: 3, 87.5: 2, 50.0: 1})
# Valence 70.0
# Counter({75.0: 5, 62.5: 3, 87.5: 1, 50.0: 1})
# Arousal 78.75
# Counter({75.0: 5, 87.5: 4, 62.5: 1})
# Valence 58.75
# Counter({62.5: 4, 50.0: 3, 75.0: 2, 37.5: 1})
# Arousal 77.5
# Counter({75.0: 5, 62.5: 2, 87.5: 2, 100.0: 1})
# Valence 65.0
# Counter({75.0: 3, 62.5: 2, 50.0: 2, 87.5: 2, 25.0: 1})
# Arousal 80.0
# Counter({87.5: 3, 75.0: 3, 100.0: 2, 62.5: 1, 50.0: 1})
# Valence 61.25
# Counter({62.5: 4, 50.0: 4, 75.0: 1, 87.5: 1})
# Arousal 82.5
# Counter({75.0: 4, 87.5: 3, 100.0: 2, 62.5: 1})
# Valence 65.0
# Counter({62.5: 6, 75.0: 2, 87.5: 1, 37.5: 1})
# Arousal 78.75
# Counter({75.0: 4, 87.5: 3, 62.5: 2, 100.0: 1})
# Valence 56.25
# Counter({62.5: 7, 37.5: 2, 50.0: 1})
# Arousal 76.25
# Counter({87.5: 5, 75.0: 2, 62.5: 2, 50.0: 1})
# Valence 66.25
# Counter({75.0: 4, 62.5: 3, 50.0: 1, 37.5: 1, 87.5: 1})
# Arousal 73.75
# Counter({75.0: 3, 62.5: 3, 87.5: 2, 100.0: 1, 50.0: 1})
# Valence 66.25
# Counter({75.0: 4, 62.5: 4, 25.0: 1, 87.5: 1})
# Arousal 80.0
# Counter({87.5: 4, 75.0: 3, 62.5: 2, 100.0: 1})
# Valence 65.0
# Counter({62.5: 4, 50.0: 3, 87.5: 2, 75.0: 1})
# Arousal 77.5
# Counter({75.0: 6, 87.5: 3, 62.5: 1})
# Valence 63.75
# Counter({50.0: 3, 87.5: 2, 62.5: 2, 75.0: 2, 37.5: 1})
# Arousal 81.25
# Counter({75.0: 4, 100.0: 3, 62.5: 2, 87.5: 1})
# Valence 62.5
# Counter({87.5: 3, 50.0: 2, 25.0: 2, 75.0: 2, 62.5: 1})
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-31246a6ddf82> in <module>
#     142 if __name__ == "__main__":
#     143      for i in range(100):
# --> 144             Run1000(30,"s21","256",30,35)
#     145 #     for i in range(1,10):
#     146 #         print("Whole video result for user s0"+str(i))
#
# <ipython-input-31-31246a6ddf82> in Run1000(Components, UserName, Window, StartTime, EndTime)
#     129     valence=[]
#     130     for i in range (10):
# --> 131         svmpca=SVMPCA(Components,UserName,Window,StartTime=0,EndTime=63)
#     132         arousal+=[svmpca[0]]
#     133         valence+=[svmpca[1]]
#
# <ipython-input-31-31246a6ddf82> in SVMPCA(Components, UserName, Window, StartTime, EndTime)
#      16     file_path = os.path.join("ChannelsExtracted",UserName, 'ValenceEncoded'+".csv")
#      17     ValenceFile =  np.genfromtxt(fname=file_path,delimiter=',').astype(int)
# ---> 18     BandsFile = np.genfromtxt('training/'+str(StartTime)+str(EndTime)+'/'+Window+UserName+'.csv',delimiter=',')
#      19     X_train, X_test, y_train, y_test , z_train,z_test= train_test_split(BandsFile, ValenceFile,ArousalFile, test_size=0.2)
#      20 #     print("Valence \n ")
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2045         rows = list(
#    2046             zip(*[[conv._loose_call(_r) for _r in map(itemgetter(i), rows)]
# -> 2047                   for (i, conv) in enumerate(converters)]))
#    2048     else:
#    2049         rows = list(
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in <listcomp>(.0)
#    2045         rows = list(
#    2046             zip(*[[conv._loose_call(_r) for _r in map(itemgetter(i), rows)]
# -> 2047                   for (i, conv) in enumerate(converters)]))
#    2048     else:
#    2049         rows = list(
#
# ~\Anaconda3\lib\site-packages\numpy\lib\npyio.py in <listcomp>(.0)
#    2044     if loose:
#    2045         rows = list(
# -> 2046             zip(*[[conv._loose_call(_r) for _r in map(itemgetter(i), rows)]
#    2047                   for (i, conv) in enumerate(converters)]))
#    2048     else:
#
# KeyboardInterrupt:
