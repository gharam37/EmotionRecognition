# %%
import numpy as np
import os
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import collections
from sklearn.metrics import f1_score
import warnings
warnings.filterwarnings('ignore')
def KNNPCA(UserName,Kv=3,Ka=5,Components=10,Window=256,StartTime=0,EndTime=63):
    file_path = os.path.join("ChannelsExtracted",UserName, 'ArousalEncoded'+".csv")
    ArousalFile =  np.genfromtxt(fname=file_path,delimiter=',').astype(int)
    file_path = os.path.join("ChannelsExtracted",UserName, 'ValenceEncoded'+".csv")
    ValenceFile =  np.genfromtxt(fname=file_path,delimiter=',').astype(int)
    BandsFile = np.genfromtxt('training/'+str(StartTime)+str(EndTime)+'/'+str(Window)+UserName+'.csv',delimiter=',')
    X_train, X_test, y_train, y_test , z_train,z_test= train_test_split(BandsFile, ValenceFile,ArousalFile, test_size=0.2)
    # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    # PCA to select features
    pca = PCA(n_components=Components, svd_solver='full')
    pca.fit(BandsFile)
    BandsFile = pca.transform(BandsFile)
       	
    # KNN classsifier
    clf = KNeighborsClassifier(n_neighbors=Kv)
    trained_model=clf.fit(X_train,y_train)
    trained_model.fit(X_train,y_train )
    
    clf.fit(X_train, y_train)
    y_predict = clf.predict(X_test)
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
        
    # PCA to select features
    pca = PCA(n_components=Components, svd_solver='full')
    pca.fit(BandsFile)
    BandsFile = pca.transform(BandsFile)
        	
    # KNN classsifier
    clf = KNeighborsClassifier(n_neighbors=Ka)
    trained_model=clf.fit(X_train,z_train)
    trained_model.fit(X_train,z_train )
    clf.fit(X_train, z_train)
    z_predict = clf.predict(X_test)
    return [accuracy_score(z_test, z_predict)*100,accuracy_score(y_test, y_predict)*100
            ,f1_score(z_test, z_predict, average='weighted'),
            f1_score(y_test, y_predict, average='weighted')]

############ Happy And Sad########################33
def KNNPCAHS(UserName,Kv=3,Ka=5,Components=10,Window=256,StartTime=0,EndTime=63):
    file_path = os.path.join("ChannelsExtracted",UserName, 'HappyAndSadEncoded'+".csv")
    SurveyFile =  np.genfromtxt(fname=file_path,delimiter=',').astype(int)
    BandsFile = np.genfromtxt('training/'+str(StartTime)+str(EndTime)+'/'+str(Window)+UserName+'HS'+'.csv',delimiter=',')
    X_train, X_test, y_train, y_test = train_test_split(BandsFile, SurveyFile, test_size=0.2)
    while ((np.sum(y_train == 0) == 0) or (np.sum(y_train == 1) == 0)): #Don't Start training unless you have 2 classes.. happens with imbalance
        print("here")
        X_train, X_test, y_train, y_test = train_test_split(BandsFile, SurveyFile, test_size=0.2)
    # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    # PCA to select features
    pca = PCA(n_components=Components, svd_solver='full')
    pca.fit(BandsFile)
    BandsFile = pca.transform(BandsFile)
    # KNN classsifier
    clf = KNeighborsClassifier(n_neighbors=Kv)
    trained_model=clf.fit(X_train,y_train)
    trained_model.fit(X_train,y_train )
    clf.fit(X_train, y_train)
    y_predict = clf.predict(X_test)
    cm = confusion_matrix(y_test, y_predict)
    return [accuracy_score(y_test, y_predict)*100,
            f1_score(y_test, y_predict, average='weighted')]


############ All Emotions########################33
def KNNPCACombined(UserName,Kv=3,Ka=5,Components=10,Window=256,StartTime=0,EndTime=63):
    file_path = os.path.join("ChannelsExtracted",UserName, 'ValenceAndArousalEncoded'+".csv")
    SurveyFile =  np.genfromtxt(fname=file_path,delimiter=',').astype(int)
    BandsFile = np.genfromtxt('training/'+str(StartTime)+str(EndTime)+'/'+str(Window)+UserName+'.csv',delimiter=',')
    X_train, X_test, y_train, y_test = train_test_split(BandsFile, SurveyFile, test_size=0.2)
    # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    # PCA to select features
    pca = PCA(n_components=Components, svd_solver='full')
    pca.fit(BandsFile)
    BandsFile = pca.transform(BandsFile)
    # KNN classsifier
    clf = KNeighborsClassifier(n_neighbors=Kv)
    trained_model=clf.fit(X_train,y_train)
    trained_model.fit(X_train,y_train )
    clf.fit(X_train, y_train)
    y_predict = clf.predict(X_test)
    cm = confusion_matrix(y_test, y_predict)
    return [accuracy_score(y_test, y_predict)*100,
            f1_score(y_test, y_predict, average='weighted')]

################ Run Each Method Multiple Times #####################
def Run100(UserName,Kv=3,Ka=5,Components=10,Window=256,StartTime=0,EndTime=63):
    arousal=[]
    valence=[]
    F1_ScoreArousal=[]
    F1_ScoreValence=[]
    for i in range (100):
        KNN=KNNPCA(UserName,Kv,Ka,Components,Window,StartTime,EndTime)
        arousal+=[KNN[0]]
        valence+=[KNN[1]]
        F1_ScoreArousal+=[KNN[2]]
        F1_ScoreValence+=[KNN[3]]
    print("Arousal "+str(np.mean(arousal)))
    print(collections.Counter(arousal))
    print("Valence "+str(np.mean(valence)))
    print(collections.Counter(valence))
    return [np.mean(arousal),np.mean(valence),np.mean(F1_ScoreArousal),np.mean(F1_ScoreValence)];
    

    
def RunCombined100(UserName,Kv=3,Ka=5,Components=10,Window=256,StartTime=0,EndTime=63):
    Combined=[]
    F1_ALL=[]
    for i in range (100):
        AllEmotions=KNNPCACombined(UserName,Kv,Ka,Components,Window,StartTime,EndTime)
        Combined+=[AllEmotions[0]]
        F1_ALL+=[AllEmotions[1]]
    print("Array of average All Emotions accurecies for user "+UserName)
    print(collections.Counter(Combined))
    return [np.mean(Combined),np.mean(F1_ALL)];
    
def RunHS100(UserName,Kv=3,Ka=5,Components=10,Window=256,StartTime=0,EndTime=63):
    Combined=[]
    F1_HS=[]
    for i in range (100):
        HS=KNNPCAHS(UserName,Kv,Ka,Components,Window,StartTime,EndTime)
        Combined+=[HS[0]]
        F1_HS+=[HS[1]]
    print("Array of average Happy Sad accurecies for user "+UserName)
    print(collections.Counter(Combined))
    return [np.mean(Combined),np.mean(F1_HS)];

##################Main#########################
if __name__ == "__main__":
    HSAccurecy=0;
    HSF1=0;
    CombinedAccurecy=0;
    CombinedF1=0;
    ValenceAccurecy=0;
    ValenceF1=0;
    ArousalAccurecy=0;
    ArousalF1=0;
    for i in range(1,10):
        print("s0"+str(i))
        #Happy and Sad
        var =RunHS100("s0"+str(i))
        print("Happy Sad")
        print(var)
        HSAccurecy+=var[0]
        HSF1+=var[1]
        #All 4 Emotions
        var1 =RunCombined100("s0"+str(i))
        print("Combined Emotions")
        print(var1)
        CombinedAccurecy+=var1[0]
        CombinedF1+=var1[1]
        #Seperated Valence and Arousal
        var2=Run100("s0"+str(i))
        print("Arousal Valence")
        print(var2)
        ArousalAccurecy+=var2[0]
        ValenceAccurecy+=var2[1]
        ArousalF1+=var2[2]
        ValenceF1+=var2[3]
    for i in range(10,33):
        print("s"+str(i))
        #Happy and Sad
        if not ("s"+str(i) == "s31"):
            var =RunHS100("s"+str(i))
            print("Happy Sad")
            print(var)
            HSAccurecy+=var[0]
            HSF1+=var[1]
        #All 4 Emotions
        var1 =RunCombined100("s"+str(i))
        print("Combined Emotions")
        print(var1)
        CombinedAccurecy+=var1[0]
        CombinedF1+=var1[1]
        #Seperated Valence and Arousal
        var2=Run100("s"+str(i))
        print("Arousal Valence")
        print(var2)
        ArousalAccurecy+=var2[0]
        ValenceAccurecy+=var2[1]
        ArousalF1+=var2[2]
    print("Accurecy happy sad for 31 users "+str(HSAccurecy/31))
    print("F1 happy sad for  31 users "+str(HSF1/31))
    print("Accurecy Combined sad for 32 users"+str(CombinedAccurecy/32))
    print("F1 Combined sad for  32 users "+str(CombinedF1/32))
    print("Accurecy Valence for  32 users "+str(ValenceAccurecy/32))
    print("F1 Valence for 32 users "+str(ValenceF1/32))
    print("Accurecy Arousal for  32 users "+str(ArousalAccurecy/32))
    print("F1 Arousal for  32 users "+str(ArousalF1/32))
# Out:
# s01
# Array of average Happy Sad accurecies for user s01
# Counter({40.0: 40, 60.0: 28, 20.0: 18, 80.0: 9, 0.0: 4, 100.0: 1})
# Happy Sad
# [44.6, 0.431952380952381]
# Array of average All Emotions accurecies for user s01
# Counter({25.0: 28, 37.5: 27, 50.0: 21, 12.5: 12, 62.5: 9, 0.0: 2, 75.0: 1})
# Combined Emotions
# [35.5, 0.3158242243867244]
# Arousal 49.0
# Counter({50.0: 30, 62.5: 21, 37.5: 20, 25.0: 12, 75.0: 11, 12.5: 3, 87.5: 2, 0.0: 1})
# Valence 48.75
# Counter({50.0: 32, 37.5: 24, 62.5: 24, 25.0: 9, 75.0: 7, 12.5: 3, 87.5: 1})
# Arousal Valence
# [49.0, 48.75, 0.45606421356421356, 0.4753245643245645]
# s02
# Array of average Happy Sad accurecies for user s02
# Counter({80.0: 50, 60.0: 23, 100.0: 22, 40.0: 4, 20.0: 1})
# Happy Sad
# [77.6, 0.7371746031746033]
# Array of average All Emotions accurecies for user s02
# Counter({37.5: 29, 50.0: 25, 25.0: 19, 62.5: 17, 75.0: 6, 12.5: 3, 87.5: 1})
# Combined Emotions
# [44.5, 0.3797475302475303]
# Arousal 62.75
# Counter({62.5: 39, 75.0: 24, 50.0: 15, 87.5: 10, 37.5: 9, 25.0: 3})
# Valence 71.875
# Counter({75.0: 35, 62.5: 22, 87.5: 22, 50.0: 13, 100.0: 5, 37.5: 3})
# Arousal Valence
# [62.75, 71.875, 0.5605190087690087, 0.7171068098568099]
# s03
# Array of average Happy Sad accurecies for user s03
# Counter({33.33333333333333: 44, 66.66666666666666: 28, 0.0: 23, 100.0: 5})
# Happy Sad
# [38.33333333333333, 0.3406666666666666]
# Array of average All Emotions accurecies for user s03
# Counter({37.5: 36, 50.0: 20, 25.0: 18, 12.5: 15, 62.5: 8, 75.0: 3})
# Combined Emotions
# [37.125, 0.3644600122100121]
# Arousal 63.5
# Counter({62.5: 36, 75.0: 30, 50.0: 23, 87.5: 6, 37.5: 4, 25.0: 1})
# Valence 62.125
# Counter({62.5: 34, 50.0: 30, 75.0: 17, 87.5: 11, 37.5: 6, 100.0: 1, 25.0: 1})
# Arousal Valence
# [63.5, 62.125, 0.6144606227106227, 0.5855365467865468]
# s04
# Array of average Happy Sad accurecies for user s04
# Counter({50.0: 35, 66.66666666666666: 29, 83.33333333333334: 21, 33.33333333333333: 7, 100.0: 4, 16.666666666666664: 4})
# Happy Sad
# [61.33333333333334, 0.6096759259259259]
# Array of average All Emotions accurecies for user s04
# Counter({37.5: 33, 50.0: 27, 25.0: 14, 62.5: 12, 75.0: 8, 12.5: 5, 0.0: 1})
# Combined Emotions
# [43.5, 0.4170496031746032]
# Arousal 51.125
# Counter({62.5: 26, 50.0: 26, 37.5: 24, 75.0: 12, 25.0: 8, 87.5: 2, 0.0: 1, 12.5: 1})
# Valence 58.5
# Counter({62.5: 31, 50.0: 29, 75.0: 16, 37.5: 13, 87.5: 7, 25.0: 2, 12.5: 1, 100.0: 1})
# Arousal Valence
# [51.125, 58.5, 0.4911176046176046, 0.579098124098124]
# s05
# Array of average Happy Sad accurecies for user s05
# Counter({83.33333333333334: 33, 66.66666666666666: 33, 100.0: 17, 50.0: 13, 33.33333333333333: 4})
# Happy Sad
# [74.33333333333333, 0.654025974025974]
# Array of average All Emotions accurecies for user s05
# Counter({50.0: 31, 37.5: 24, 25.0: 20, 62.5: 13, 12.5: 7, 0.0: 2, 75.0: 2, 87.5: 1})
# Combined Emotions
# [40.875, 0.3173739177489177]
# Arousal 49.125
# Counter({50.0: 29, 62.5: 23, 37.5: 17, 25.0: 12, 75.0: 9, 12.5: 5, 87.5: 4, 0.0: 1})
# Valence 71.25
# Counter({75.0: 35, 62.5: 28, 87.5: 20, 50.0: 14, 100.0: 3})
# Arousal Valence
# [49.125, 71.25, 0.43626975801975815, 0.6775212287712287]
# s06
# Array of average Happy Sad accurecies for user s06
# Counter({75.0: 59, 100.0: 29, 50.0: 10, 25.0: 2})
# Happy Sad
# [78.75, 0.7174761904761904]
# Array of average All Emotions accurecies for user s06
# Counter({50.0: 27, 62.5: 26, 37.5: 21, 25.0: 12, 75.0: 7, 12.5: 5, 87.5: 1, 0.0: 1})
# Combined Emotions
# [47.375, 0.4258829989454989]
# Arousal 41.25
# Counter({37.5: 23, 25.0: 23, 62.5: 20, 50.0: 19, 12.5: 9, 75.0: 5, 0.0: 1})
# Valence 77.25
# Counter({75.0: 43, 87.5: 30, 62.5: 12, 100.0: 8, 50.0: 5, 37.5: 2})
# Arousal Valence
# [41.25, 77.25, 0.3936624486624487, 0.7164875124875123]
# s07
# Array of average Happy Sad accurecies for user s07
# Counter({80.0: 54, 100.0: 24, 60.0: 18, 40.0: 4})
# Happy Sad
# [79.6, 0.724531746031746]
# Array of average All Emotions accurecies for user s07
# Counter({37.5: 33, 50.0: 27, 25.0: 15, 62.5: 14, 12.5: 7, 75.0: 3, 0.0: 1})
# Combined Emotions
# [41.5, 0.3377303113553114]
# Arousal 55.125
# Counter({50.0: 31, 62.5: 26, 75.0: 18, 37.5: 18, 25.0: 5, 87.5: 1, 100.0: 1})
# Valence 64.125
# Counter({62.5: 30, 75.0: 28, 50.0: 22, 87.5: 11, 37.5: 6, 25.0: 2, 100.0: 1})
# Arousal Valence
# [55.125, 64.125, 0.48501254301254304, 0.6033410755910755]
# s08
# Array of average Happy Sad accurecies for user s08
# Counter({80.0: 54, 100.0: 22, 60.0: 21, 40.0: 3})
# Happy Sad
# [79.0, 0.7357539682539683]
# Array of average All Emotions accurecies for user s08
# Counter({50.0: 30, 62.5: 24, 75.0: 16, 37.5: 13, 25.0: 10, 87.5: 5, 12.5: 2})
# Combined Emotions
# [54.0, 0.4379154942279942]
# Arousal 76.875
# Counter({75.0: 37, 87.5: 30, 62.5: 19, 100.0: 8, 50.0: 6})
# Valence 72.125
# Counter({75.0: 34, 87.5: 26, 62.5: 19, 50.0: 14, 100.0: 4, 37.5: 2, 25.0: 1})
# Arousal Valence
# [76.875, 72.125, 0.6911181318681316, 0.6795989288489288]
# s09
# Array of average Happy Sad accurecies for user s09
# Counter({66.66666666666666: 47, 83.33333333333334: 32, 50.0: 12, 100.0: 7, 33.33333333333333: 1, 16.666666666666664: 1})
# Happy Sad
# [71.49999999999999, 0.7039663299663299]
# Array of average All Emotions accurecies for user s09
# Counter({50.0: 28, 62.5: 21, 25.0: 18, 37.5: 17, 75.0: 11, 12.5: 4, 87.5: 1})
# Combined Emotions
# [47.625, 0.4207342934842934]
# Arousal 69.75
# Counter({62.5: 33, 75.0: 28, 87.5: 15, 50.0: 13, 100.0: 7, 37.5: 4})
# Valence 64.375
# Counter({62.5: 30, 75.0: 28, 50.0: 15, 87.5: 12, 37.5: 11, 100.0: 2, 25.0: 2})
# Arousal Valence
# [69.75, 64.375, 0.6182345432345433, 0.6464739427239427]
# s10
# Array of average Happy Sad accurecies for user s10
# Counter({75.0: 36, 50.0: 36, 25.0: 17, 100.0: 9, 0.0: 2})
# Happy Sad
# [58.25, 0.5488571428571428]
# Array of average All Emotions accurecies for user s10
# Counter({37.5: 43, 25.0: 29, 50.0: 13, 12.5: 7, 0.0: 4, 62.5: 4})
# Combined Emotions
# [33.25, 0.31274206349206346]
# Arousal 54.625
# Counter({62.5: 34, 50.0: 30, 37.5: 13, 75.0: 12, 25.0: 6, 87.5: 2, 12.5: 2, 100.0: 1})
# Valence 61.75
# Counter({62.5: 33, 75.0: 25, 50.0: 21, 37.5: 7, 87.5: 7, 25.0: 4, 100.0: 2, 12.5: 1})
# Arousal Valence
# [54.625, 61.75, 0.534977022977023, 0.6088518981018981]
# s11
# Array of average Happy Sad accurecies for user s11
# Counter({75.0: 41, 50.0: 31, 100.0: 17, 25.0: 9, 0.0: 2})
# Happy Sad
# [65.5, 0.6307619047619046]
# Array of average All Emotions accurecies for user s11
# Counter({37.5: 37, 25.0: 25, 12.5: 20, 50.0: 11, 62.5: 5, 75.0: 1, 0.0: 1})
# Combined Emotions
# [32.0, 0.28558315295815295]
# Arousal 52.625
# Counter({50.0: 28, 37.5: 21, 62.5: 21, 75.0: 17, 25.0: 7, 12.5: 3, 87.5: 2, 100.0: 1})
# Valence 55.125
# Counter({50.0: 35, 62.5: 29, 37.5: 15, 75.0: 15, 25.0: 3, 87.5: 2, 12.5: 1})
# Arousal Valence
# [52.625, 55.125, 0.5137121212121213, 0.5076042568542569]
# s12
# here
# here
# here
# here
# here
# here
# here
# Array of average Happy Sad accurecies for user s12
# Counter({100.0: 63, 80.0: 37})
# Happy Sad
# [92.6, 0.8931111111111111]
# Array of average All Emotions accurecies for user s12
# Counter({50.0: 29, 62.5: 22, 37.5: 20, 25.0: 14, 75.0: 10, 12.5: 3, 87.5: 2})
# Combined Emotions
# [48.875, 0.4441438075813076]
# Arousal 86.625
# Counter({87.5: 36, 100.0: 35, 75.0: 18, 62.5: 9, 50.0: 2})
# Valence 59.25
# Counter({62.5: 32, 50.0: 24, 75.0: 16, 37.5: 12, 87.5: 11, 25.0: 4, 12.5: 1})
# Arousal Valence
# [86.625, 59.25, 0.809650183150183, 0.5794250194250194]
# s13
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Array of average Happy Sad accurecies for user s13
# Counter({100.0: 100})
# Happy Sad
# [100.0, 1.0]
# Array of average All Emotions accurecies for user s13
# Counter({75.0: 32, 50.0: 26, 62.5: 20, 87.5: 14, 37.5: 7, 25.0: 1})
# Combined Emotions
# [64.625, 0.6151109376734376]
# Arousal 85.125
# Counter({87.5: 41, 75.0: 28, 100.0: 24, 62.5: 6, 50.0: 1})
# Valence 69.25
# Counter({62.5: 32, 75.0: 31, 50.0: 17, 87.5: 15, 100.0: 4, 37.5: 1})
# Arousal Valence
# [85.125, 69.25, 0.8001556776556775, 0.6910457042957043]
# s14
# Array of average Happy Sad accurecies for user s14
# Counter({100.0: 41, 75.0: 38, 50.0: 14, 25.0: 7})
# Happy Sad
# [78.25, 0.735238095238095]
# Array of average All Emotions accurecies for user s14
# Counter({50.0: 42, 62.5: 19, 37.5: 18, 25.0: 12, 75.0: 5, 87.5: 3, 12.5: 1})
# Combined Emotions
# [49.125, 0.46161210317460316]
# Arousal 66.75
# Counter({75.0: 34, 62.5: 26, 50.0: 15, 87.5: 13, 37.5: 7, 100.0: 3, 25.0: 2})
# Valence 66.625
# Counter({75.0: 32, 62.5: 25, 50.0: 18, 87.5: 11, 37.5: 9, 100.0: 5})
# Arousal Valence
# [66.75, 66.625, 0.6276520979020979, 0.6627407037407039]
# s15
# Array of average Happy Sad accurecies for user s15
# Counter({50.0: 44, 75.0: 31, 25.0: 19, 0.0: 4, 100.0: 2})
# Happy Sad
# [52.0, 0.49933333333333335]
# Array of average All Emotions accurecies for user s15
# Counter({37.5: 35, 25.0: 29, 12.5: 16, 50.0: 12, 62.5: 5, 0.0: 2, 75.0: 1})
# Combined Emotions
# [32.25, 0.3059781746031746]
# Arousal 47.5
# Counter({37.5: 30, 50.0: 28, 62.5: 20, 25.0: 14, 75.0: 6, 87.5: 2})
# Valence 64.0
# Counter({62.5: 34, 50.0: 25, 75.0: 24, 87.5: 11, 37.5: 3, 25.0: 2, 100.0: 1})
# Arousal Valence
# [47.5, 64.0, 0.45555988455988455, 0.6299243256743257]
# s16
# Array of average Happy Sad accurecies for user s16
# Counter({80.0: 54, 100.0: 26, 60.0: 15, 40.0: 4, 20.0: 1})
# Happy Sad
# [80.0, 0.7827777777777777]
# Array of average All Emotions accurecies for user s16
# Counter({37.5: 33, 50.0: 26, 62.5: 18, 25.0: 10, 75.0: 8, 12.5: 4, 87.5: 1})
# Combined Emotions
# [46.5, 0.4208293650793651]
# Arousal 67.125
# Counter({75.0: 28, 62.5: 27, 50.0: 19, 87.5: 18, 37.5: 4, 25.0: 2, 100.0: 2})
# Valence 62.875
# Counter({62.5: 31, 50.0: 26, 75.0: 25, 87.5: 9, 37.5: 7, 25.0: 1, 100.0: 1})
# Arousal Valence
# [67.125, 62.875, 0.6730858585858586, 0.5823239260739261]
# s17
# Array of average Happy Sad accurecies for user s17
# Counter({80.0: 41, 100.0: 30, 60.0: 19, 40.0: 10})
# Happy Sad
# [78.2, 0.7442619047619047]
# Array of average All Emotions accurecies for user s17
# Counter({50.0: 29, 37.5: 26, 25.0: 22, 62.5: 13, 75.0: 7, 12.5: 2, 0.0: 1})
# Combined Emotions
# [43.375, 0.39234469696969687]
# Arousal 67.0
# Counter({62.5: 33, 75.0: 31, 87.5: 13, 50.0: 10, 37.5: 5, 100.0: 4, 25.0: 3, 12.5: 1})
# Valence 54.25
# Counter({62.5: 32, 50.0: 31, 37.5: 18, 75.0: 11, 25.0: 4, 87.5: 3, 12.5: 1})
# Arousal Valence
# [67.0, 54.25, 0.6431457153957153, 0.5328994338994338]
# s18
# Array of average Happy Sad accurecies for user s18
# Counter({100.0: 51, 80.0: 38, 60.0: 9, 40.0: 2})
# Happy Sad
# [87.6, 0.8531349206349205]
# Array of average All Emotions accurecies for user s18
# Counter({50.0: 30, 62.5: 24, 37.5: 19, 75.0: 12, 25.0: 12, 12.5: 2, 87.5: 1})
# Combined Emotions
# [50.25, 0.43424297924297917]
# Arousal 52.0
# Counter({50.0: 33, 37.5: 27, 62.5: 25, 75.0: 11, 25.0: 2, 12.5: 1, 87.5: 1})
# Valence 83.625
# Counter({87.5: 40, 100.0: 24, 75.0: 21, 62.5: 11, 50.0: 4})
# Arousal Valence
# [52.0, 83.625, 0.44113475413475406, 0.8022073759573759]
# s19
# Array of average Happy Sad accurecies for user s19
# Counter({83.33333333333334: 37, 66.66666666666666: 35, 100.0: 15, 50.0: 11, 33.33333333333333: 2})
# Happy Sad
# [75.33333333333334, 0.6896220538720538]
# Array of average All Emotions accurecies for user s19
# Counter({37.5: 32, 50.0: 27, 25.0: 18, 62.5: 9, 12.5: 7, 75.0: 7})
# Combined Emotions
# [41.75, 0.34698785242535246]
# Arousal 67.125
# Counter({62.5: 39, 75.0: 32, 50.0: 13, 87.5: 10, 37.5: 4, 100.0: 2})
# Valence 67.75
# Counter({75.0: 30, 62.5: 28, 87.5: 16, 50.0: 15, 37.5: 5, 100.0: 4, 12.5: 1, 25.0: 1})
# Arousal Valence
# [67.125, 67.75, 0.5572514152514153, 0.6612217782217782]
# s20
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Array of average Happy Sad accurecies for user s20
# Counter({100.0: 100})
# Happy Sad
# [100.0, 1.0]
# Array of average All Emotions accurecies for user s20
# Counter({37.5: 30, 62.5: 30, 50.0: 26, 75.0: 7, 25.0: 4, 12.5: 3})
# Combined Emotions
# [49.625, 0.46231868131868126]
# Arousal 85.125
# Counter({87.5: 37, 100.0: 27, 75.0: 27, 62.5: 8, 50.0: 1})
# Valence 55.25
# Counter({62.5: 34, 50.0: 26, 37.5: 18, 75.0: 14, 25.0: 4, 87.5: 3, 12.5: 1})
# Arousal Valence
# [85.125, 55.25, 0.7875329670329668, 0.5635874958374958]
# s21
# Array of average Happy Sad accurecies for user s21
# Counter({80.0: 49, 100.0: 44, 60.0: 7})
# Happy Sad
# [87.4, 0.8217222222222224]
# Array of average All Emotions accurecies for user s21
# Counter({50.0: 35, 37.5: 22, 62.5: 19, 25.0: 14, 75.0: 6, 12.5: 3, 87.5: 1})
# Combined Emotions
# [46.875, 0.4265696178821177]
# Arousal 78.0
# Counter({75.0: 43, 87.5: 35, 62.5: 13, 100.0: 5, 50.0: 4})
# Valence 58.625
# Counter({50.0: 35, 62.5: 31, 75.0: 15, 87.5: 8, 37.5: 7, 25.0: 3, 12.5: 1})
# Arousal Valence
# [78.0, 58.625, 0.7154358974358972, 0.5829676434676435]
# s22
# Array of average Happy Sad accurecies for user s22
# Counter({75.0: 48, 100.0: 27, 50.0: 21, 25.0: 4})
# Happy Sad
# [74.5, 0.6985238095238094]
# Array of average All Emotions accurecies for user s22
# Counter({50.0: 33, 62.5: 21, 37.5: 21, 75.0: 13, 25.0: 8, 12.5: 2, 87.5: 2})
# Combined Emotions
# [51.25, 0.4598890692640692]
# Arousal 70.0
# Counter({75.0: 32, 62.5: 26, 87.5: 14, 50.0: 12, 100.0: 9, 37.5: 6, 25.0: 1})
# Valence 62.75
# Counter({62.5: 37, 75.0: 24, 50.0: 18, 87.5: 9, 37.5: 8, 25.0: 3, 100.0: 1})
# Arousal Valence
# [70.0, 62.75, 0.6667319902319904, 0.6279025974025974]
# s23
# Array of average Happy Sad accurecies for user s23
# Counter({60.0: 48, 40.0: 31, 80.0: 9, 20.0: 6, 100.0: 5, 0.0: 1})
# Happy Sad
# [54.6, 0.4941587301587302]
# Array of average All Emotions accurecies for user s23
# Counter({37.5: 37, 50.0: 26, 25.0: 22, 62.5: 9, 12.5: 5, 75.0: 1})
# Combined Emotions
# [39.375, 0.3613474927849928]
# Arousal 49.5
# Counter({62.5: 28, 50.0: 25, 37.5: 21, 25.0: 11, 75.0: 10, 12.5: 4, 87.5: 1})
# Valence 73.25
# Counter({75.0: 36, 62.5: 26, 87.5: 20, 50.0: 11, 100.0: 7})
# Arousal Valence
# [49.5, 73.25, 0.4978523698523698, 0.6893754578754577]
# s24
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Array of average Happy Sad accurecies for user s24
# Counter({100.0: 100})
# Happy Sad
# [100.0, 1.0]
# Array of average All Emotions accurecies for user s24
# Counter({50.0: 34, 62.5: 27, 37.5: 19, 25.0: 8, 12.5: 7, 75.0: 5})
# Combined Emotions
# [47.625, 0.4535459054834054]
# Arousal 88.5
# Counter({87.5: 46, 100.0: 33, 75.0: 17, 62.5: 4})
# Valence 56.125
# Counter({50.0: 31, 62.5: 31, 37.5: 17, 75.0: 14, 87.5: 3, 25.0: 3, 100.0: 1})
# Arousal Valence
# [88.5, 56.125, 0.8419395604395603, 0.5623272005772004]
# s25
# here
# here
# here
# Array of average Happy Sad accurecies for user s25
# Counter({100.0: 67, 75.0: 33})
# Happy Sad
# [91.75, 0.8821428571428571]
# Array of average All Emotions accurecies for user s25
# Counter({50.0: 29, 37.5: 27, 25.0: 19, 62.5: 11, 12.5: 7, 75.0: 5, 0.0: 2})
# Combined Emotions
# [40.875, 0.3656412337662338]
# Arousal 72.5
# Counter({75.0: 42, 62.5: 26, 87.5: 18, 50.0: 7, 100.0: 5, 37.5: 1, 12.5: 1})
# Valence 58.5
# Counter({62.5: 29, 50.0: 26, 75.0: 20, 37.5: 15, 87.5: 7, 25.0: 2, 12.5: 1})
# Arousal Valence
# [72.5, 58.5, 0.670636419136419, 0.5679432789432789]
# s26
# Array of average Happy Sad accurecies for user s26
# Counter({71.42857142857143: 30, 57.14285714285714: 28, 42.857142857142854: 21, 85.71428571428571: 11, 28.57142857142857: 7, 100.0: 2, 14.285714285714285: 1})
# Happy Sad
# [59.99999999999999, 0.6022012987012986]
# Array of average All Emotions accurecies for user s26
# Counter({50.0: 32, 37.5: 30, 62.5: 21, 25.0: 8, 12.5: 5, 75.0: 4})
# Combined Emotions
# [46.0, 0.41158044733044735]
# Arousal 54.0
# Counter({50.0: 29, 62.5: 27, 25.0: 14, 75.0: 12, 37.5: 10, 87.5: 6, 12.5: 1, 100.0: 1})
# Valence 57.25
# Counter({62.5: 30, 50.0: 22, 75.0: 16, 37.5: 15, 87.5: 8, 25.0: 7, 100.0: 1, 12.5: 1})
# Arousal Valence
# [54.0, 57.25, 0.5343665223665224, 0.5784644522144522]
# s27
# Array of average Happy Sad accurecies for user s27
# Counter({83.33333333333334: 48, 100.0: 29, 66.66666666666666: 17, 50.0: 6})
# Happy Sad
# [83.33333333333334, 0.7835353535353535]
# Array of average All Emotions accurecies for user s27
# Counter({50.0: 32, 62.5: 29, 75.0: 14, 37.5: 13, 87.5: 7, 25.0: 4, 100.0: 1})
# Combined Emotions
# [57.625, 0.49920897158397154]
# Arousal 68.75
# Counter({75.0: 37, 62.5: 29, 50.0: 16, 87.5: 15, 37.5: 2, 100.0: 1})
# Valence 80.125
# Counter({87.5: 41, 75.0: 32, 100.0: 11, 62.5: 10, 50.0: 6})
# Arousal Valence
# [68.75, 80.125, 0.6686714119214118, 0.771970695970696]
# s28
# Array of average Happy Sad accurecies for user s28
# Counter({50.0: 38, 66.66666666666666: 24, 33.33333333333333: 22, 83.33333333333334: 8, 16.666666666666664: 6, 100.0: 1, 0.0: 1})
# Happy Sad
# [50.99999999999999, 0.4961031746031746]
# Array of average All Emotions accurecies for user s28
# Counter({25.0: 34, 37.5: 25, 12.5: 23, 50.0: 13, 0.0: 3, 62.5: 2})
# Combined Emotions
# [28.5, 0.24374440836940836]
# Arousal 33.75
# Counter({37.5: 35, 25.0: 24, 50.0: 16, 12.5: 13, 62.5: 8, 0.0: 4})
# Valence 67.625
# Counter({75.0: 32, 62.5: 28, 50.0: 17, 87.5: 16, 37.5: 4, 100.0: 2, 12.5: 1})
# Arousal Valence
# [33.75, 67.625, 0.32086291486291485, 0.6728526751026753]
# s29
# Array of average Happy Sad accurecies for user s29
# Counter({66.66666666666666: 35, 50.0: 28, 83.33333333333334: 28, 33.33333333333333: 5, 100.0: 4})
# Happy Sad
# [66.33333333333334, 0.6640547138047138]
# Array of average All Emotions accurecies for user s29
# Counter({50.0: 36, 37.5: 20, 62.5: 18, 25.0: 13, 75.0: 11, 87.5: 2})
# Combined Emotions
# [50.0, 0.4542354728604729]
# Arousal 72.625
# Counter({62.5: 35, 75.0: 35, 87.5: 17, 100.0: 7, 50.0: 4, 25.0: 1, 37.5: 1})
# Valence 59.0
# Counter({62.5: 31, 50.0: 24, 75.0: 22, 37.5: 11, 25.0: 6, 87.5: 4, 100.0: 2})
# Arousal Valence
# [72.625, 59.0, 0.693811494061494, 0.586838023088023]
# s30
# Array of average Happy Sad accurecies for user s30
# Counter({57.14285714285714: 36, 42.857142857142854: 29, 71.42857142857143: 23, 28.57142857142857: 5, 85.71428571428571: 5, 14.285714285714285: 2})
# Happy Sad
# [55.42857142857143, 0.5386985236985237]
# Array of average All Emotions accurecies for user s30
# Counter({50.0: 41, 37.5: 20, 62.5: 18, 25.0: 15, 75.0: 6})
# Combined Emotions
# [47.5, 0.4079178876678877]
# Arousal 52.5
# Counter({62.5: 29, 50.0: 28, 37.5: 16, 75.0: 14, 25.0: 12, 87.5: 1})
# Valence 57.375
# Counter({62.5: 34, 50.0: 30, 75.0: 16, 37.5: 13, 87.5: 4, 25.0: 3})
# Arousal Valence
# [52.5, 57.375, 0.4968659396159396, 0.5385782550782551]
# s31
# Array of average All Emotions accurecies for user s31
# Counter({37.5: 33, 50.0: 27, 25.0: 24, 62.5: 8, 12.5: 6, 0.0: 1, 75.0: 1})
# Combined Emotions
# [38.375, 0.3889154942279942]
# Arousal 56.25
# Counter({62.5: 34, 50.0: 25, 75.0: 15, 37.5: 14, 25.0: 6, 87.5: 5, 12.5: 1})
# Valence 83.625
# Counter({87.5: 33, 100.0: 27, 75.0: 24, 62.5: 14, 50.0: 2})
# Arousal Valence
# [56.25, 83.625, 0.5262014929514929, 0.8223026973026972]
# s32
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# Array of average Happy Sad accurecies for user s32
# Counter({100.0: 100})
# Happy Sad
# [100.0, 1.0]
# Array of average All Emotions accurecies for user s32
# Counter({25.0: 34, 37.5: 29, 50.0: 16, 12.5: 14, 62.5: 4, 0.0: 3})
# Combined Emotions
# [31.625, 0.3088184523809524]
# Arousal 66.75
# Counter({75.0: 37, 62.5: 29, 50.0: 15, 87.5: 10, 37.5: 7, 100.0: 2})
# Valence 45.5
# Counter({50.0: 28, 37.5: 28, 62.5: 14, 25.0: 13, 75.0: 10, 12.5: 5, 0.0: 1, 87.5: 1})
# Arousal Valence
# [66.75, 45.5, 0.6338268398268397, 0.44528246753246753]
# Accurecy happy sad for 31 users 74.10092165898617
# F1 happy sad for first 31 users 0.7101117004262165
# Accurecy Combined sad for 32 users44.0390625
# F1 Combined sad for first 32 users 0.39625083293442664
# Accurecy Valence for first 32 users 64.05859375
# F1 Valence for first 30 0.18934962444962444
# Accurecy Arousal for first 32 users 62.9140625
# F1 Arousal for first 32 users 0.5892974820318568
